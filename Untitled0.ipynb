# %% [markdown]
# <a href="https://colab.research.google.com/github/jessicaa2345/ChocoTurbo/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

prompts = [
    "Quais bairros são atendidos pela ChocoTurbo?",
    "A entrega funciona aos domingos?",
    "Não encontro o app da ChocoTurbo nas lojas digitais.",
    "É possível visitar a fábrica da ChocoTurbo?",
    "Posso pagar com vale-alimentação?",
    "Desejo cancelar um pedido que acabei de fazer.",
    "Quero alterar o endereço de entrega após a compra.",
    "É possível agendar uma entrega para o fim do dia?",
    "Posso enviar o pedido para um endereço diferente do cadastro?",
    "Meu pedido está atrasado.",
    "Os produtos contêm glúten?",
    "Quero uma caixa sortida com diferentes sabores.",
    "Vocês têm chocolates veganos?",
    "Meu pedido veio errado, o que faço?",
    "Como posso enviar sugestões de melhoria?"
]

# Respostas simuladas diferentes para cada prompt (5 por prompt)
respostas = [
    [
        "Atendemos os principais bairros da região metropolitana, consulte no nosso site o seu CEP.",
        "Nossa entrega cobre as cidades centrais e arredores, sempre atualizando a área de atendimento.",
        "Você pode verificar a lista de bairros atendidos diretamente em nosso aplicativo ou site.",
        "Estamos ampliando a área de entrega para novos bairros em breve, fique atento às atualizações.",
        "Para confirmar se atendemos seu bairro, insira seu CEP no campo de consulta em nosso site."
    ],
    [
        "Sim, entregamos normalmente aos domingos, das 10h às 22h.",
        "Nosso delivery funciona todos os dias, inclusive domingos, para sua comodidade.",
        "A entrega aos domingos é garantida, faça seu pedido tranquilamente.",
        "Domingo é dia de chocolate! Operamos das 10h às 22h sem interrupções.",
        "Estamos à disposição para entregas aos domingos no horário comercial informado."
    ],
    [
        "Baixe nosso app procurando 'ChocoTurbo' na Google Play ou App Store.",
        "Nosso aplicativo está disponível nas principais lojas, faça a busca por nome.",
        "Se não encontrar o app, tente limpar o cache da loja digital e buscar novamente.",
        "O app pode ser baixado gratuitamente nas lojas Android e iOS, disponível já!",
        "Caso tenha dificuldades, acesse o site e faça seu pedido diretamente por lá."
    ],
    [
        "No momento, não realizamos visitas à fábrica, mas você pode acompanhar pelo blog.",
        "Nossa fábrica está fechada para visitas, focamos na qualidade e segurança da produção.",
        "Agradecemos o interesse, porém não oferecemos tours presenciais atualmente.",
        "Não fazemos visitas físicas, mas temos vídeos exclusivos mostrando o processo de fabricação.",
        "Fique ligado nas redes sociais para ver os bastidores da produção artesanal."
    ],
    [
        "Ainda não aceitamos vale-alimentação, mas temos outras opções como cartão e Pix.",
        "Vale-alimentação não é aceito, porém cartões e dinheiro estão disponíveis.",
        "Por enquanto, o pagamento via vale-alimentação não está disponível no nosso sistema.",
        "Aceitamos diversos meios, mas o vale-alimentação ainda não é uma opção.",
        "Recomendamos usar cartão de crédito, débito, Pix ou dinheiro no ato da entrega."
    ],
    [
        "Cancelamento só é possível antes do despacho, entre em contato urgente.",
        "Se o pedido não saiu para entrega, podemos cancelar, fale conosco rapidamente.",
        "Assim que realizar o pedido, entre em contato para tentarmos cancelar a tempo.",
        "Após o despacho, cancelamento não é possível, então avise logo para evitar transtornos.",
        "Nosso suporte está disponível para verificar cancelamentos antes da entrega."
    ],
    [
        "Alteração do endereço só antes do pedido ser enviado, contate nosso atendimento.",
        "Se ainda não despachamos, podemos atualizar seu endereço, entre em contato rápido.",
        "Informe o novo endereço o quanto antes para avaliarmos a alteração.",
        "Endereço só pode ser modificado se o pedido não tiver sido despachado ainda.",
        "Nosso time pode ajudar a alterar o endereço desde que o pedido esteja no prazo."
    ],
    [
        "Não oferecemos agendamento, as entregas são feitas sob demanda.",
        "Por enquanto, só realizamos entregas imediatas, agendamento será implementado futuramente.",
        "Pedidos devem ser feitos próximo ao horário desejado, não há agendamento disponível.",
        "Estamos trabalhando para habilitar agendamento, mas hoje não está disponível.",
        "Recomendamos fazer o pedido no momento em que deseja receber para melhor atendimento."
    ],
    [
        "Sim, você pode informar um endereço de entrega diferente no checkout.",
        "Durante a finalização do pedido, preencha o campo de endereço para entrega desejado.",
        "É possível enviar para outro endereço, basta indicar corretamente no pedido.",
        "A flexibilidade para endereço é permitida no processo de compra.",
        "Você pode alterar o endereço de entrega desde que feito antes da confirmação final."
    ],
    [
        "Lamentamos o atraso, estamos trabalhando para que seu pedido chegue logo.",
        "Pode haver atrasos por trânsito ou volume, agradecemos a paciência.",
        "Nosso time monitora sua entrega para minimizar o tempo de espera.",
        "Estamos cientes do atraso e faremos o possível para regularizar o quanto antes.",
        "Agradecemos a compreensão, estamos tomando providências para melhorar a entrega."
    ],
    [
        "Oferecemos diversas opções sem glúten, todas identificadas no cardápio.",
        "Temos produtos especialmente feitos para dietas sem glúten.",
        "Nossos chocolates sem glúten são preparados em ambiente controlado.",
        "Garantimos opções seguras para pessoas com restrição ao glúten.",
        "Consulte nosso catálogo online para ver todos os produtos sem glúten."
    ],
    [
        "Sim, temos caixas sortidas com sabores variados, escolha a sua preferida.",
        "Oferecemos seleção especial em caixas sortidas para diferentes gostos.",
        "Monte sua caixa personalizada com vários sabores disponíveis.",
        "Nossas caixas sortidas são ideais para experimentar diferentes chocolates.",
        "Caixas sortidas estão disponíveis no site para compra rápida e prática."
    ],
    [
        "Temos uma linha exclusiva de chocolates veganos em nosso cardápio.",
        "Nossos chocolates veganos são livres de ingredientes animais e muito saborosos.",
        "Para opções veganas, selecione a categoria específica em nosso app ou site.",
        "Garantimos produtos veganos com ingredientes certificados e de qualidade.",
        "Confira nossos chocolates veganos disponíveis para entrega rápida."
    ],
    [
        "Pedimos desculpas pelo erro. Entre em contato imediatamente para resolvermos.",
        "Vamos corrigir seu pedido ou oferecer reembolso, fale com nosso suporte.",
        "Por favor, comunique o problema para que possamos providenciar a solução.",
        "Nosso atendimento está pronto para ajudar com trocas ou reembolsos.",
        "Garantimos solução rápida para pedidos entregues errados, contate-nos."
    ],
    [
        "Envie suas sugestões para sugestoes@chocoturbo.com, agradecemos seu feedback.",
        "Sua opinião é importante! Mande sugestões pelo e-mail indicado.",
        "Estamos abertos a melhorias, encaminhe suas ideias por e-mail.",
        "Queremos ouvir você! Use nosso canal de sugestões via e-mail.",
        "Contribua com a gente enviando sugestões para o endereço eletrônico oficial."
    ]
]

# Criar um dicionário para o DataFrame
dados = {"Prompt": [], "Resposta 1": [], "Resposta 2": [], "Resposta 3": [], "Resposta 4": [], "Resposta 5": []}

for i, prompt in enumerate(prompts):
    dados["Prompt"].append(prompt)
    for j in range(5):
        chave = f"Resposta {j+1}"
        dados[chave].append(respostas[i][j])

df = pd.DataFrame(dados)

df
# Out:
#                                                Prompt  \
# 0        Quais bairros são atendidos pela ChocoTurbo?
# 1                    A entrega funciona aos domingos?
# 2   Não encontro o app da ChocoTurbo nas lojas dig...
# 3         É possível visitar a fábrica da ChocoTurbo?
# 4                   Posso pagar com vale-alimentação?
# 5      Desejo cancelar um pedido que acabei de fazer.
# 6   Quero alterar o endereço de entrega após a com...
# 7   É possível agendar uma entrega para o fim do dia?
# 8   Posso enviar o pedido para um endereço diferen...
# 9                           Meu pedido está atrasado.
# 10                         Os produtos contêm glúten?
# 11    Quero uma caixa sortida com diferentes sabores.
# 12                      Vocês têm chocolates veganos?
# 13                Meu pedido veio errado, o que faço?
# 14           Como posso enviar sugestões de melhoria?
#
#                                            Resposta 1  \
# ...
